# %% [markdown]
# <a href="https://colab.research.google.com/github/nhwie1705/nlp/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests

#cài đặt thư viện
# !pip uninstall -y torch torchtext torchdata
# !pip install -U spacy torch torchtext
# !python -m spacy download en_core_web_sm
# !python -m spacy download fr_core_news_sm
# !pip install torch==2.3.1 torchtext==0.18.0

# 2. Tải file Raw từ Multi30K (Task 1)
urls = [
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/train.en",
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/train.fr",
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/val.en",
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/val.fr",
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/test.en",
    "https://raw.githubusercontent.com/multi30k/dataset/master/data/task1/raw/test.fr"
]

print("\nĐang tải dữ liệu raw...")
print("\n ------------------")
for url in urls:
    filename = url.split("/")[-1]
    if not os.path.exists(filename):
        r = requests.get(url)
        with open(filename, "wb") as f:
            f.write(r.content)
        print(f"-> Đã tải: {filename}")
    else:
        print(f"-> {filename} đã có sẵn.")

print("\n ------------------")
print("\n Tải raw hoàn tất")
# Out:
# Found existing installation: torch 2.3.1
# Uninstalling torch-2.3.1:
#   Successfully uninstalled torch-2.3.1
# Found existing installation: torchtext 0.18.0
# Uninstalling torchtext-0.18.0:
#   Successfully uninstalled torchtext-0.18.0
# WARNING: Skipping torchdata as it is not installed.
# ...
#   Using cached torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ...
#   Using cached torchtext-0.18.0-cp312-cp312-manylinux1_x86_64.whl.metadata (7.9 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ...

# %%
import torch
import spacy
from torchtext.vocab import build_vocab_from_iterator
import io

try:
    spacy_en = spacy.load("en_core_web_sm")
    spacy_fr = spacy.load("fr_core_news_sm")
except OSError:
    print("Lỗi!")

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

def tokenize_fr(text):
    return [tok.text for tok in spacy_fr.tokenizer(text)]

def yield_tokens(file_path, tokenizer):
    with io.open(file_path, encoding='utf-8') as f:
        for line in f:
            yield tokenizer(line.strip())

special_symbols = ['<unk>', '<pad>', '<sos>', '<eos>']
UNK_IDX, PAD_IDX, SOS_IDX, EOS_IDX = 0, 1, 2, 3

print("\n ------------------")
print("\n Đang tạo từ điển...")

# Từ điển Anh
vocab_en = build_vocab_from_iterator(
    yield_tokens('train.en', tokenize_en),
    min_freq=2,
    specials=special_symbols,
    max_tokens=10000
)
vocab_en.set_default_index(UNK_IDX)

# Từ điển Pháp
vocab_fr = build_vocab_from_iterator(
    yield_tokens('train.fr', tokenize_fr),
    min_freq=2,
    specials=special_symbols,
    max_tokens=10000
)
vocab_fr.set_default_index(UNK_IDX)

print(f"Đã tạo từ điển tiếng anh với {len(vocab_en)} từ")
print(f"Đã tạo từ điển tiếng pháp với {len(vocab_fr)} từ")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.12/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
#  ------------------
#
#  Đang tạo từ điển...
# Đã tạo từ điển tiếng anh với 4 từ
# Đã tạo từ điển tiếng pháp với 4 từ
